# %%
from pathlib import Path
print('# Gemma 4 31B — Kaggle TPU v5e-8 — G3 authority')
print(Path('requirements-tpu-g3.txt').read_text())
print('MODEL_PRESET=gemma4_instruct_31b')
print('MODEL_DTYPE=bfloat16')
print('TPU_EXPECTED_DEVICES=8')
print('MESH_SHAPE=[1, 8], MESH_AXES=[batch, model]')

# %%
# !bash scripts/run_g3_tpu_authority.sh

# %%
import json
from pathlib import Path
latest = sorted(Path('/kaggle/working').glob('gemma4-31b-vnext-g3-authority-*/07-authority-result.json'))[-1]
print(json.dumps(json.loads(latest.read_text()), indent=2, sort_keys=True))
